# %%
import numpy as np

# %%
class chain_env():
    
    def __init__(self, N):        
        self.N = N
        self.current_state = 1
        self.timer = 0
        self.action_space = [-1, 1]
        
    def step(self, act):
        assert act in self.action_space
        done = 0
        rew = self.reward(act)
        info  = []
        
        self.timer = self.timer + 1
        self.current_state = self.current_state + act
        
        if self.current_state >= self.N:
            self.current_state = self.N - 1
        if self.current_state < 0:
            self.current_state = 0
            
        if self.timer == self.N + 9:
            done = 1
            
        return self.therm_encoding(self.current_state), rew, done, info            
        
            
    def reward(self, act):        
        if self.current_state == self.N and act == 1:
            return 1
        if self.current_state == 0 and act == -1:
            return 1e-3
        return 0
        
    def reset(self):
        self.current_state = 1
        self.timer = 0
        return self.therm_encoding(self.current_state)
        
    def therm_encoding(self, x):
    
        state = np.zeros(self.N)
        state[:x] = 1
        return state

# %%
if __name__ == '__main__':
    
    env = chain_env(20)
    done = False
    obs = env.reset()
    act = 2*np.random.binomial(1, 0.5) - 1

    episode_rew = 0
    episode_count = 0

    for i in range(10000):
        if done:

            print("Episode " + str(episode_count) + " reward = " + str(episode_rew))
            episode_rew = 0
            episode_count = episode_count + 1

            obs = env.reset()
            act = 2*np.random.binomial(1, 0.5) - 1

        obs, rew, done = env.step(act)    
        act = 2*np.random.binomial(1, 0.5) - 1

        episode_rew = episode_rew + rew
# Out:
# Episode 0 reward = 0.008
# Episode 1 reward = 0.003
# Episode 2 reward = 0.002
# Episode 3 reward = 0.006
# Episode 4 reward = 0
# Episode 5 reward = 0.003
# Episode 6 reward = 0.008
# Episode 7 reward = 0.003
# Episode 8 reward = 0.004
# Episode 9 reward = 0.003
# Episode 10 reward = 0
# Episode 11 reward = 0
# Episode 12 reward = 0.001
# Episode 13 reward = 0.002
# Episode 14 reward = 0
# Episode 15 reward = 0
# Episode 16 reward = 0
# Episode 17 reward = 0.003
# Episode 18 reward = 0.007
# Episode 19 reward = 0.002
# Episode 20 reward = 0
# Episode 21 reward = 0.003
# Episode 22 reward = 0.004
# Episode 23 reward = 0.002
# Episode 24 reward = 0.003
# Episode 25 reward = 0.002
# Episode 26 reward = 0.002
# Episode 27 reward = 0.010000000000000002
# Episode 28 reward = 0.002
# Episode 29 reward = 0.004
# Episode 30 reward = 0
# Episode 31 reward = 0.004
# Episode 32 reward = 0.003
# Episode 33 reward = 0.002
# Episode 34 reward = 0.008
# Episode 35 reward = 0.003
# Episode 36 reward = 0
# Episode 37 reward = 0.007
# Episode 38 reward = 0.011000000000000003
# Episode 39 reward = 0.002
# Episode 40 reward = 0.004
# Episode 41 reward = 0.002
# Episode 42 reward = 0
# Episode 43 reward = 0.005
# Episode 44 reward = 0
# Episode 45 reward = 0.005
# Episode 46 reward = 0.002
# Episode 47 reward = 0.003
# Episode 48 reward = 0
# Episode 49 reward = 0.001
# Episode 50 reward = 0.002
# Episode 51 reward = 0.007
# Episode 52 reward = 0.001
# Episode 53 reward = 0
# Episode 54 reward = 0.001
# Episode 55 reward = 0.004
# Episode 56 reward = 0
# Episode 57 reward = 0.002
# Episode 58 reward = 0.002
# Episode 59 reward = 0.001
# Episode 60 reward = 0.002
# Episode 61 reward = 0.002
# Episode 62 reward = 0.002
# Episode 63 reward = 0.001
# Episode 64 reward = 0.002
# Episode 65 reward = 0.004
# Episode 66 reward = 0.002
# Episode 67 reward = 0.003
# Episode 68 reward = 0.002
# Episode 69 reward = 0
# Episode 70 reward = 0.003
# Episode 71 reward = 0.003
# Episode 72 reward = 0
# Episode 73 reward = 0
# Episode 74 reward = 0
# Episode 75 reward = 0.009000000000000001
# Episode 76 reward = 0.004
# Episode 77 reward = 0.002
# Episode 78 reward = 0.004
# Episode 79 reward = 0.006
# Episode 80 reward = 0.008
# Episode 81 reward = 0.004
# Episode 82 reward = 0.004
# Episode 83 reward = 0.006
# Episode 84 reward = 0.002
# Episode 85 reward = 0.005
# Episode 86 reward = 0
# Episode 87 reward = 0.007
# Episode 88 reward = 0
# Episode 89 reward = 0
# Episode 90 reward = 0.001
# Episode 91 reward = 0
# Episode 92 reward = 0
# Episode 93 reward = 0
# Episode 94 reward = 0.001
# Episode 95 reward = 0
# Episode 96 reward = 0.008
# Episode 97 reward = 0.001
# Episode 98 reward = 0
# Episode 99 reward = 0.006
# Episode 100 reward = 0.001
# Episode 101 reward = 0
# Episode 102 reward = 0
# Episode 103 reward = 0.001
# Episode 104 reward = 0
# Episode 105 reward = 0
# Episode 106 reward = 0.002
# Episode 107 reward = 0.006
# Episode 108 reward = 0.001
# Episode 109 reward = 0.003
# Episode 110 reward = 0.005
# Episode 111 reward = 0.001
# Episode 112 reward = 0
# Episode 113 reward = 0.001
# Episode 114 reward = 0
# Episode 115 reward = 0.004
# Episode 116 reward = 0.004
# Episode 117 reward = 0.003
# Episode 118 reward = 0.001
# Episode 119 reward = 0.007
# Episode 120 reward = 0
# Episode 121 reward = 0
# Episode 122 reward = 0.005
# Episode 123 reward = 0.004
# Episode 124 reward = 0.006
# Episode 125 reward = 0.001
# Episode 126 reward = 0
# Episode 127 reward = 0.002
# Episode 128 reward = 0
# Episode 129 reward = 0
# Episode 130 reward = 0
# Episode 131 reward = 0.001
# Episode 132 reward = 0.003
# Episode 133 reward = 0
# Episode 134 reward = 0.003
# Episode 135 reward = 0.014000000000000005
# Episode 136 reward = 0.006
# Episode 137 reward = 0.004
# Episode 138 reward = 0.005
# Episode 139 reward = 0.003
# Episode 140 reward = 0.001
# Episode 141 reward = 0
# Episode 142 reward = 0.011000000000000003
# Episode 143 reward = 0
# Episode 144 reward = 0.003
# Episode 145 reward = 0
# Episode 146 reward = 0
# Episode 147 reward = 0.001
# Episode 148 reward = 0.002
# Episode 149 reward = 0.001
# Episode 150 reward = 0.002
# Episode 151 reward = 0.001
# Episode 152 reward = 0.001
# Episode 153 reward = 0.003
# Episode 154 reward = 0.007
# Episode 155 reward = 0.002
# Episode 156 reward = 0.004
# Episode 157 reward = 0
# Episode 158 reward = 0
# Episode 159 reward = 0
# Episode 160 reward = 0.003
# Episode 161 reward = 0.003
# Episode 162 reward = 0.006
# Episode 163 reward = 0
# Episode 164 reward = 0.008
# Episode 165 reward = 0.005
# Episode 166 reward = 0.005
# Episode 167 reward = 0
# Episode 168 reward = 0.008
# Episode 169 reward = 0.002
# Episode 170 reward = 0.002
# Episode 171 reward = 0
# Episode 172 reward = 0.006
# Episode 173 reward = 0.010000000000000002
# Episode 174 reward = 0
# Episode 175 reward = 0.001
# Episode 176 reward = 0.006
# Episode 177 reward = 0
# Episode 178 reward = 0.004
# Episode 179 reward = 0.001
# Episode 180 reward = 0
# Episode 181 reward = 0.010000000000000002
# Episode 182 reward = 0
# Episode 183 reward = 0
# Episode 184 reward = 0.010000000000000002
# Episode 185 reward = 0
# Episode 186 reward = 0.001
# Episode 187 reward = 0.002
# Episode 188 reward = 0.002
# Episode 189 reward = 0.004
# Episode 190 reward = 0.006
# Episode 191 reward = 0
# Episode 192 reward = 0
# Episode 193 reward = 0.012000000000000004
# Episode 194 reward = 0.006
# Episode 195 reward = 0.003
# Episode 196 reward = 0.002
# Episode 197 reward = 0.005
# Episode 198 reward = 0.001
# Episode 199 reward = 0.002
# Episode 200 reward = 0.004
# Episode 201 reward = 0
# Episode 202 reward = 0
# Episode 203 reward = 0.007
# Episode 204 reward = 0
# Episode 205 reward = 0
# Episode 206 reward = 0.005
# Episode 207 reward = 0.001
# Episode 208 reward = 0.005
# Episode 209 reward = 0
# Episode 210 reward = 0
# Episode 211 reward = 0.007
# Episode 212 reward = 0
# Episode 213 reward = 0.004
# Episode 214 reward = 0
# Episode 215 reward = 0
# Episode 216 reward = 0.006
# Episode 217 reward = 0.008
# Episode 218 reward = 0.001
# Episode 219 reward = 0.001
# Episode 220 reward = 0.003
# Episode 221 reward = 0.002
# Episode 222 reward = 0.001
# Episode 223 reward = 0.011000000000000003
# Episode 224 reward = 0.003
# Episode 225 reward = 0.002
# Episode 226 reward = 0
# Episode 227 reward = 0.003
# Episode 228 reward = 0.002
# Episode 229 reward = 0.008
# Episode 230 reward = 0
# Episode 231 reward = 0.004
# Episode 232 reward = 0.008
# Episode 233 reward = 0
# Episode 234 reward = 0.001
# Episode 235 reward = 0
# Episode 236 reward = 0.007
# Episode 237 reward = 0.001
# Episode 238 reward = 0.006
# Episode 239 reward = 0.002
# Episode 240 reward = 0.005
# Episode 241 reward = 0.001
# Episode 242 reward = 0
# Episode 243 reward = 0.001
# Episode 244 reward = 0.002
# Episode 245 reward = 0
# Episode 246 reward = 0.002
# Episode 247 reward = 0.008
# Episode 248 reward = 0.002
# Episode 249 reward = 0.001
# Episode 250 reward = 0
# Episode 251 reward = 0.011000000000000003
# Episode 252 reward = 0.003
# Episode 253 reward = 0.007
# Episode 254 reward = 0.001
# Episode 255 reward = 0.003
# Episode 256 reward = 0.010000000000000002
# Episode 257 reward = 0.003
# Episode 258 reward = 0
# Episode 259 reward = 0.004
# Episode 260 reward = 0.010000000000000002
# Episode 261 reward = 0.003
# Episode 262 reward = 0.006
# Episode 263 reward = 0.006
# Episode 264 reward = 0.004
# Episode 265 reward = 0.005
# Episode 266 reward = 0.006
# Episode 267 reward = 0
# Episode 268 reward = 0.002
# Episode 269 reward = 0.006
# Episode 270 reward = 0.003
# Episode 271 reward = 0.008
# Episode 272 reward = 0
# Episode 273 reward = 0.008
# Episode 274 reward = 0.002
# Episode 275 reward = 0.009000000000000001
# Episode 276 reward = 0.003
# Episode 277 reward = 0
# Episode 278 reward = 0
# Episode 279 reward = 0
# Episode 280 reward = 0.006
# Episode 281 reward = 0.006
# Episode 282 reward = 0.005
# Episode 283 reward = 0.003
# Episode 284 reward = 0.007
# Episode 285 reward = 0.005
# Episode 286 reward = 0.004
# Episode 287 reward = 0.003
# Episode 288 reward = 0.001
# Episode 289 reward = 0
# Episode 290 reward = 0
# Episode 291 reward = 0.001
# Episode 292 reward = 0.007
# Episode 293 reward = 0.002
# Episode 294 reward = 0
# Episode 295 reward = 0
# Episode 296 reward = 0.004
# Episode 297 reward = 0.001
# Episode 298 reward = 0.003
# Episode 299 reward = 0.010000000000000002
# Episode 300 reward = 0
# Episode 301 reward = 0.004
# Episode 302 reward = 0
# Episode 303 reward = 0.007
# Episode 304 reward = 0.006
# Episode 305 reward = 0
# Episode 306 reward = 0
# Episode 307 reward = 0
# Episode 308 reward = 0.008
# Episode 309 reward = 0.011000000000000003
# Episode 310 reward = 0.001
# Episode 311 reward = 0
# Episode 312 reward = 0
# Episode 313 reward = 0.002
# Episode 314 reward = 0.002
# Episode 315 reward = 0.002
# Episode 316 reward = 0.001
# Episode 317 reward = 0.002
# Episode 318 reward = 0
# Episode 319 reward = 0.010000000000000002
# Episode 320 reward = 0
# Episode 321 reward = 0.005
# Episode 322 reward = 0.005
# Episode 323 reward = 0.005
# Episode 324 reward = 0
# Episode 325 reward = 0.006
# Episode 326 reward = 0
# Episode 327 reward = 0.001
# Episode 328 reward = 0.002
# Episode 329 reward = 0
# Episode 330 reward = 0.005
# Episode 331 reward = 0.003
# Episode 332 reward = 0.009000000000000001
# Episode 333 reward = 0.006
# Episode 334 reward = 0.006
# Episode 335 reward = 0.008
# Episode 336 reward = 0
# Episode 337 reward = 0
# Episode 338 reward = 0
# Episode 339 reward = 0
# Episode 340 reward = 0.002
# Episode 341 reward = 0.007
# Episode 342 reward = 0.002
# Episode 343 reward = 0
